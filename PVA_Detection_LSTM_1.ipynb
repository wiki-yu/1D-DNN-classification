# %%
# LSTM with dropout for sequence classification in the IMDB dataset
import numpy
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence

# %%
# fix random seed for reproducibility
numpy.random.seed(7)
# load the dataset but only keep the top n words, zero the rest
top_words = 5000
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=top_words)
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz
# 17465344/17464789 [==============================] - 2s 0us/step

# %%
# truncate and pad input sequences
max_review_length = 500
X_train = sequence.pad_sequences(X_train, maxlen=max_review_length)
X_test = sequence.pad_sequences(X_test, maxlen=max_review_length)

# %%
print(numpy.shape(X_train))
print(X_train)
# Out:
# (25000, 500)
# [[   0    0    0 ...   19  178   32]
#  [   0    0    0 ...   16  145   95]
#  [   0    0    0 ...    7  129  113]
#  ...
#  [   0    0    0 ...    4 3586    2]
#  [   0    0    0 ...   12    9   23]
#  [   0    0    0 ...  204  131    9]]

# %%
# create the model
embedding_vecor_length = 32
model = Sequential()
model.add(Embedding(top_words, embedding_vecor_length, input_length=max_review_length))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 500, 32)           160000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               53200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 213,301
# Trainable params: 213,301
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(X_train, y_train, epochs=3, batch_size=64)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/3
# 25000/25000 [==============================] - 567s 23ms/step - loss: 0.4857 - accuracy: 0.7686
# Epoch 2/3
# 25000/25000 [==============================] - 560s 22ms/step - loss: 0.3805 - accuracy: 0.8396
# Epoch 3/3
# 25000/25000 [==============================] - 555s 22ms/step - loss: 0.3440 - accuracy: 0.8589
# Accuracy: 84.20%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from keras import optimizers, losses, activations, models
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from keras.layers import Dense, Input, Dropout, Convolution1D, MaxPool1D, GlobalMaxPool1D, GlobalAveragePooling1D, concatenate
import glob
import os
# Out:
# Using TensorFlow backend.

# %%
# !rm -rf ventmap waveforms labels *.csv
# !unzip ventmap.zip 
# !unzip waveforms.zip 
# !unzip labels.zip
# Out:
# Archive:  ventmap.zip
#    creating: ventmap/
#   inflating: ventmap/add_timestamp_to_file.py
#   inflating: ventmap/anonymize_datatimes.py
#   inflating: ventmap/breath_meta.py
#   inflating: ventmap/clear_null_bytes.py
#   inflating: ventmap/constants.py
#   inflating: ventmap/convert_3_col_file_to_2_col.py
#   inflating: ventmap/cut_breath_section.py
#   inflating: ventmap/detection.py
#   inflating: ventmap/preprocess_all_files.py
#   inflating: ventmap/raw_utils.py
#   inflating: ventmap/rounding_rules.py
#   inflating: ventmap/SAM.py
#  extracting: ventmap/__init__.py
# Archive:  waveforms.zip
#    creating: waveforms/
#    creating: waveforms/1/
#    creating: waveforms/10/
#   inflating: waveforms/10/1008cut.csv
#    creating: waveforms/11/
#   inflating: waveforms/11/1009cut.csv
#    creating: waveforms/12/
#   inflating: waveforms/12/1010_1cut.csv
#    creating: waveforms/13/
#   inflating: waveforms/13/1010_2cut.csv
#    creating: waveforms/14/
#   inflating: waveforms/14/1011cut.csv
#    creating: waveforms/15/
#   inflating: waveforms/15/1012cut.csv
#    creating: waveforms/16/
#   inflating: waveforms/16/1013cut.csv
#    creating: waveforms/17/
#   inflating: waveforms/17/1014cut.csv
#    creating: waveforms/18/
#   inflating: waveforms/18/1015cut.csv
#    creating: waveforms/19/
#   inflating: waveforms/19/1016cut.csv
#   inflating: waveforms/1/1000cut.csv
#    creating: waveforms/2/
#    creating: waveforms/20/
#   inflating: waveforms/20/1017cut.csv
#    creating: waveforms/21/
#   inflating: waveforms/21/1018cut.csv
#    creating: waveforms/22/
#   inflating: waveforms/22/1019cut.csv
#    creating: waveforms/23/
#   inflating: waveforms/23/1020cut.csv
#    creating: waveforms/24/
#   inflating: waveforms/24/1021cut.csv
#    creating: waveforms/25/
#   inflating: waveforms/25/1022cut.csv
#    creating: waveforms/26/
#   inflating: waveforms/26/1023cut.csv
#    creating: waveforms/27/
#   inflating: waveforms/27/1024cut.csv
#    creating: waveforms/28/
#   inflating: waveforms/28/1025cut.csv
#    creating: waveforms/29/
#   inflating: waveforms/29/1026cut.csv
#   inflating: waveforms/2/1001_1cut.csv
#    creating: waveforms/3/
#    creating: waveforms/30/
#   inflating: waveforms/30/1027cut.csv
#    creating: waveforms/31/
#   inflating: waveforms/31/1028cut.csv
#    creating: waveforms/32/
#   inflating: waveforms/32/1029cut.csv
#    creating: waveforms/33/
#   inflating: waveforms/33/1030cut.csv
#    creating: waveforms/34/
#   inflating: waveforms/34/1031cut.csv
#    creating: waveforms/35/
#   inflating: waveforms/35/1032cut.csv
#    creating: waveforms/36/
#   inflating: waveforms/36/1033cut.csv
#    creating: waveforms/37/
#   inflating: waveforms/37/1034cut.csv
#   inflating: waveforms/3/1001_2cut.csv
#    creating: waveforms/4/
#   inflating: waveforms/4/1002cut.csv
#    creating: waveforms/5/
#   inflating: waveforms/5/1003cut.csv
#    creating: waveforms/6/
#   inflating: waveforms/6/1004cut.csv
#    creating: waveforms/7/
#   inflating: waveforms/7/1005cut.csv
#    creating: waveforms/8/
#   inflating: waveforms/8/1006cut.csv
#    creating: waveforms/9/
#   inflating: waveforms/9/1007cut.csv
# Archive:  labels.zip
#    creating: labels/
#    creating: labels/1/
#    creating: labels/10/
#   inflating: labels/10/1008goldstd.csv
#    creating: labels/11/
#   inflating: labels/11/1009goldstd.csv
#    creating: labels/12/
#   inflating: labels/12/1010_1goldstd.csv
#    creating: labels/13/
#   inflating: labels/13/1010_2goldstd.csv
#    creating: labels/14/
#   inflating: labels/14/1011goldstd.csv
#    creating: labels/15/
#   inflating: labels/15/1012goldstd.csv
#    creating: labels/16/
#   inflating: labels/16/1013goldstd.csv
#    creating: labels/17/
#   inflating: labels/17/1014goldstd.csv
#    creating: labels/18/
#   inflating: labels/18/1015goldstd.csv
#    creating: labels/19/
#   inflating: labels/19/1016goldstd.csv
#   inflating: labels/1/1000goldstd.csv
#    creating: labels/2/
#    creating: labels/20/
#   inflating: labels/20/1017_750to801_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/21/
#   inflating: labels/21/1018_1388to1689_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/22/
#   inflating: labels/22/1019_1000to1300_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/23/
#   inflating: labels/23/1020_326to376_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/24/
#   inflating: labels/24/1021_2550to2850_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/25/
#   inflating: labels/25/1022_1to301_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/26/
#   inflating: labels/26/1023_2000to2300_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/27/
#   inflating: labels/27/1024_251to301_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/28/
#   inflating: labels/28/1025_1650to1950_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/29/
#   inflating: labels/29/1026_3510to3810_goldstd_dbl_bs_cosumtvd.csv
#   inflating: labels/2/1001_1goldstd.csv
#    creating: labels/3/
#    creating: labels/30/
#   inflating: labels/30/1027_2070to2371_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/31/
#   inflating: labels/31/1028_4100to4400_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/32/
#   inflating: labels/32/1029_13300to13600_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/33/
#   inflating: labels/33/1030_4400to4700_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/34/
#   inflating: labels/34/1031_7300to7600_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/35/
#   inflating: labels/35/1032_300to600_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/36/
#   inflating: labels/36/1033_100to400_goldstd_dbl_bs_cosumtvd.csv
#    creating: labels/37/
#   inflating: labels/37/1034_18450to18750_goldstd_dbl_bs_cosumtvd.csv
#   inflating: labels/3/1001_2goldstd.csv
#    creating: labels/4/
#   inflating: labels/4/1002goldstd.csv
#    creating: labels/5/
#   inflating: labels/5/1003goldstd.csv
#    creating: labels/6/
#   inflating: labels/6/1004goldstd.csv
#    creating: labels/7/
#   inflating: labels/7/1005goldstd.csv
#    creating: labels/8/
#   inflating: labels/8/1006goldstd.csv
#    creating: labels/9/
#   inflating: labels/9/1007goldstd.csv

# %%
from io import open
from ventmap.raw_utils import extract_raw

# breaths
flow_list = []
pressure_list = []

for (dir_path, dir_names, file_names) in os.walk('./waveforms'):
    for file in file_names:
        csv_path = os.path.join(dir_path, file)
        print(csv_path)
        generator = extract_raw(open(csv_path), False)
        for breath in generator:
            # breath data is output in dictionary format
            flow, pressure = breath['flow'], breath['pressure']
            flow_list.append(flow)
            pressure_list.append(pressure)
# Out:
# ./waveforms/26/1023cut.csv
# ./waveforms/30/1027cut.csv
# ./waveforms/37/1034cut.csv
# ./waveforms/8/1006cut.csv
# ./waveforms/18/1015cut.csv
# ./waveforms/31/1028cut.csv
# ./waveforms/5/1003cut.csv
# ./waveforms/13/1010_2cut.csv
# ./waveforms/7/1005cut.csv
# ./waveforms/11/1009cut.csv
# ./waveforms/23/1020cut.csv
# ./waveforms/9/1007cut.csv
# ./waveforms/1/1000cut.csv
# ./waveforms/2/1001_1cut.csv
# ./waveforms/24/1021cut.csv
# ./waveforms/28/1025cut.csv
# ./waveforms/29/1026cut.csv
# ./waveforms/22/1019cut.csv
# ./waveforms/25/1022cut.csv
# ./waveforms/19/1016cut.csv
# ./waveforms/15/1012cut.csv
# ./waveforms/21/1018cut.csv
#  list([-1.06, 10.51, 32.1, 57.47, 75.37, 80.55, 70.2, 59.64, 51.33, 51.74, 45.74, 41.82, 41.08, 39.5, 40.03, 43.82, 46.16, 48.15, 46.41, 44.33, 43.79, 42.9, 43.21, 42.84, 39.27, 39.19, 37.78, 37.37, 36.52, 35.09, 34.31, 35.01, 33.98, 34.07, 32.94, 33.11, 32.21, 31.09, 31.56, 29.32, 29.72, -52.28, -67.0, -59.81, -38.14, -27.43, -28.21, -34.97, -35.65, -34.0, -32.5, -31.1, -31.05, -29.2, -28.61, -28.86, -27.93, -26.12, -26.27, -26.25, -25.43, -24.61, -23.6, -22.65, -22.44, -21.98, -21.32, -20.05, -20.23, -19.54, -19.58, -19.67, -19.42, -18.3, -17.62, -17.92, -16.05, -16.17, -15.32, -15.52, -15.11, -13.97, -13.6, -13.3, -13.22, -12.5, -13.02, -12.54, -12.53, -12.31, -12.02, -11.25, -11.27, -11.42, -10.79, -9.43, -9.54, -9.5, -9.12, -8.58, -8.72, -8.09, -8.13, -7.29, -7.29, -7.03, -6.9, -6.87, -6.71, -6.44, -6.14, -5.94, -6.5, -6.37, -5.98, -5.98, -6.04, -5.59, -5.11, -5.13, -4.92, -4.49, -4.3, -4.79, -5.05, -4.87, -4.56, -4.16, -4.29, -4.23, -4.17, -4.12, -3.92, -3.61, -3.22, -3.09, -3.33, -3.21, -3.23, -3.56, -3.66, -3.64, -3.3, -3.18, -3.57, -3.94, -3.82, -3.76, -3.83, -3.68, -3.43, -3.39, -3.16, -3.39, -3.27, -3.11, -2.7, -2.74, -2.84, -3.17, -3.42, -3.38, -3.2, -2.93, -2.81, -2.83, -2.75, -2.76, -2.64, -2.26, -1.93, -1.95, -1.79, -1.79, -1.9, -2.09, -2.06, -1.95, -1.72, -1.72, -1.79, -1.63, -1.75, -1.95, -2.03, -2.11, -2.01, -2.12, -1.76, -1.86, -1.91, -1.7, -1.67, -1.53, -1.55, -1.79, -2.29, -2.43, -2.34, -2.01, -1.67, -1.52, -1.37, -1.58, -1.71, -1.07, -0.71, -0.64, -0.67, -0.74, -1.05, -1.26, -1.33, -0.95, -0.49])]

# %%
label_list = []
for (dir_path, dir_names, file_names) in os.walk('./labels'):
    for file in file_names:
        csv_path = os.path.join(dir_path, file)
        print(csv_path)
        df = pd.read_csv(csv_path)
        df_filter = df[['dbl', 'mt', 'bs', 'co', 'su']]
        label_list.append(df_filter)
df_total = pd.concat(label_list, axis=0, ignore_index=True)
# df_total.describe()
df_total.to_csv("label_total.csv")
notation = df_total.to_numpy()
# Out:
# ./labels/26/1023_2000to2300_goldstd_dbl_bs_cosumtvd.csv
# ./labels/30/1027_2070to2371_goldstd_dbl_bs_cosumtvd.csv
# ./labels/37/1034_18450to18750_goldstd_dbl_bs_cosumtvd.csv
# ./labels/8/1006goldstd.csv
# ./labels/18/1015goldstd.csv
# ./labels/31/1028_4100to4400_goldstd_dbl_bs_cosumtvd.csv
# ./labels/5/1003goldstd.csv
# ./labels/13/1010_2goldstd.csv
# ./labels/7/1005goldstd.csv
# ./labels/11/1009goldstd.csv
# ./labels/23/1020_326to376_goldstd_dbl_bs_cosumtvd.csv
# ./labels/9/1007goldstd.csv
# ./labels/1/1000goldstd.csv
# ./labels/2/1001_1goldstd.csv
# ./labels/24/1021_2550to2850_goldstd_dbl_bs_cosumtvd.csv
# ./labels/28/1025_1650to1950_goldstd_dbl_bs_cosumtvd.csv
# ./labels/29/1026_3510to3810_goldstd_dbl_bs_cosumtvd.csv
# ./labels/22/1019_1000to1300_goldstd_dbl_bs_cosumtvd.csv
# ./labels/25/1022_1to301_goldstd_dbl_bs_cosumtvd.csv
# ./labels/19/1016goldstd.csv
# ./labels/15/1012goldstd.csv
# ./labels/21/1018_1388to1689_goldstd_dbl_bs_cosumtvd.csv
# ./labels/10/1008goldstd.csv
# ./labels/35/1032_300to600_goldstd_dbl_bs_cosumtvd.csv
# ./labels/14/1011goldstd.csv
# ./labels/27/1024_251to301_goldstd_dbl_bs_cosumtvd.csv
# ./labels/3/1001_2goldstd.csv
# ./labels/6/1004goldstd.csv
# ./labels/4/1002goldstd.csv
# ./labels/20/1017_750to801_goldstd_dbl_bs_cosumtvd.csv
# ./labels/34/1031_7300to7600_goldstd_dbl_bs_cosumtvd.csv
# ./labels/32/1029_13300to13600_goldstd_dbl_bs_cosumtvd.csv
# ./labels/16/1013goldstd.csv
# ./labels/33/1030_4400to4700_goldstd_dbl_bs_cosumtvd.csv
# ./labels/36/1033_100to400_goldstd_dbl_bs_cosumtvd.csv
# ./labels/12/1010_1goldstd.csv
# ./labels/17/1014goldstd.csv

# %%
def check_notation(i):
    if notation[i][0] == 1:
        label = 1 #"dbl"
    elif notation[i][1] == 1:
        label = 2 #"mt"
    elif notation[i][2] == 1:
        label = 3 #"bs"
    elif notation[i][3] == 1:
        label = 4 #"co"
    elif notation[i][4] == 1:
        label = 5 #"su"
    else:
        label = 0 #"normal"
    return label

# %%
# truncate and pad input sequences
max_review_length = 215
flow_arr = sequence.pad_sequences(flow_list, max_review_length)
pressure_arr = sequence.pad_sequences(pressure_list, max_review_length)

# %%
print(flow_arr)
# Out:
# [[ 0  0  0 ...  0  2  2]
#  [ 0  0  0 ...  0  1  2]
#  [ 0  0  0 ... -2  0  1]
#  ...
#  [-1 10 31 ... -1 -1 -1]
#  [-1 10 32 ...  0 -1  0]
#  [-1 10 32 ... -1  0  0]]

# %%
waveforms = np.hstack((flow_arr, pressure_arr))
print(np.shape(waveforms))
# Out:
# (9719, 430)

# %%
labels = []
for i, pressure in enumerate(pressure_list):
    label = check_notation(i)
    labels.append(label)
label_arr = np.array(labels)

# %%
# create the model
embedding_vecor_length = 32
model = Sequential()
model.add(Embedding(top_words, embedding_vecor_length, input_length=430))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 430, 32)           160000
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 100)               53200
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 213,301
# Trainable params: 213,301
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(waveforms, label_arr, epochs=3, batch_size=64)
# Final evaluation of the model
# Out:
# Epoch 1/3
# 9719/9719 [==============================] - 197s 20ms/step - loss: -12.4467 - accuracy: 0.4455
# Epoch 2/3
# 9719/9719 [==============================] - 196s 20ms/step - loss: -14.4717 - accuracy: 0.4067
# Epoch 3/3
# 9719/9719 [==============================] - 195s 20ms/step - loss: -18.8956 - accuracy: 0.4202

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
